# %% [markdown]
# #**Arithmetc Operator**
# ##Create two variable a and b.
# ##Print addition, subtraction, multiplication, division, floor division,modulus and exponent.

# %% [markdown]
# ##Addition

# %%
a=30
b=20
print(a+b)
# Out:
# 50

# %% [markdown]
# ##Subtraction

# %%
a=30
b=20
print(a-b)
# Out:
# 10

# %% [markdown]
# ##Multiplication

# %%
a=30
b=20
print(a*b)
# Out:
# 600

# %% [markdown]
# ##Division

# %%
a=30
b=20
print(a/b)
# Out:
# 1.5

# %% [markdown]
# ##Floor Division

# %%
a=30
b=20
print(a//b)
# Out:
# 1

# %% [markdown]
# ##Modulus

# %%
a=30
b=20
print(a%b)
# Out:
# 10

# %% [markdown]
# ##Exponent

# %%
a=3
b=2
print(a**b)
# Out:
# 9

# %% [markdown]
# #Logical Operator
# ##Take markes from input.Print pass if marks >=40,otherwise fail.

# %%
pass_marks=40
pass_marks=int(input("Please Enter Your Marks"))

if pass_marks >=40:
  print("Pass")
else:
  print("Fale")
# Out:
# Please Enter Your Marks46
# Pass

# %%
Pass_student=["Ram","Shyam","Hari","Rita"]
student_name=input("Enter student Name:")

if student_name in Pass_student :
  print("pass")
else:
  print("Fail")
# Out:
# Enter student Name:gita
# Fail

# %% [markdown]
# #Take age and citizenship status.
# ##Check if a person is eligible to vote using and.

# %%
age=20
has_id="true"
print(age >=18 and has_id)
# Out:
# False

# %%
age=17
has_id="true"
print(age >=18 and has_id)
# Out:
# False

# %%
age=25
has_id="False"
print(age >=18 and has_id)
# Out:
# False

# %% [markdown]
# #Check if a number is even or odd using the modulus operator

# %%
number=29
if number %2==0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
number=34
if number %2==0 :
  print("even")
else:
  print("odd")
# Out:
# odd

# %% [markdown]
# #Assignment
# Use +=,-=, and /= to update a score variable step by step

# %%
Score = 60
Score +=5
Score -=12
Score /=2
print(Score)
# Out:
# 26.5

# %% [markdown]
# #Project
# Write a program that calculate average marks of 3 student and check if average >=60

# %%
English=80
Nepali=70
Math=60
average=(English+Nepali+Math)/3
if average >=60 and Math >=40 :
  print("passed the good average")
else:
  print("needs improvemnt")
# Out:
# passed the good average
