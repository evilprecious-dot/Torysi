# %% [markdown]
# <a href="https://colab.research.google.com/github/evilprecious-dot/Torysi/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# one value to multipal variable

# %%
x,y,z='orange','apple','mango'
print(x)
print(y)
print(z)
# Out:
# orange
# apple
# mango

# %%
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
x="python"
y="is"
z="awesome"
print(x+y+z)
# Out:
# pythonisawesome

# %% [markdown]
# value if str and int is tuple

# %%
a=(1)
print(type(a))
# Out:
# <class 'int'>

# %%
carname='volvo'
print(carname)
# Out:
# volvo

# %%
fruits=["apple","orange","mango"]
fruits=a,b,c
print(a)
print(b)
print(c)
# Out:
# apple
# orange
# mango

# %%
a=60
b=70
print(str(a)+str(b))
print(a+b)
print(str(a)+"+"+str(b))
# Out:
# 6070
# 130
# 60+70

# %%
a=2
b="apple"
c=1.2
d=a,b,c,1
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'tuple'>
